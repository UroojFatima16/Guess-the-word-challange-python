# %%
import random
count = 0
list_words = ['life','rain','game','code','sign','road','hope','need']
words = random.choice(list_words)
while count < 3:
    print('''
    <<<<< GUESS WORD FROM GIVEN LIST>>>> 
    
          1. LIFE
          2. RAIN
          3. GAME
          4. CODE
          5. SIGN
          6. ROAD
          7. HOPE
          8. NEED
          9. COLD
          10.MARS''')
    
    guess = input("\nEnter a letter to guess: ").lower()
    if guess == words:
        print("\n\t\tcorrect guess..CONGRATULATIONS!!🤩🤩") 
        break
        
    else:
        if count < 2:
            print("\n\t\tTry Again..😢")
        count = count + 1
        
        if count == 3:
            print('\n\t\tBetter Luck Next Time..🙂🙂')
# Out:
#     <<<<< GUESS WORD FROM GIVEN LIST>>>>
#
#           1. LIFE
#           2. RAIN
#           3. GAME
#           4. CODE
#           5. SIGN
#           6. ROAD
#           7. HOPE
#           8. NEED
#           9. COLD
#           10.MARS
#
# Enter a letter to guess: life
#
# 		Try Again..😢
#
#     <<<<< GUESS WORD FROM GIVEN LIST>>>>
#
#           1. LIFE
#           2. RAIN
#           3. GAME
#           4. CODE
#           5. SIGN
#           6. ROAD
#           7. HOPE
#           8. NEED
#           9. COLD
#           10.MARS
#
# Enter a letter to guess: life
#
# 		Try Again..😢
#
#     <<<<< GUESS WORD FROM GIVEN LIST>>>>
#
#           1. LIFE
#           2. RAIN
#           3. GAME
#           4. CODE
#           5. SIGN
#           6. ROAD
#           7. HOPE
#           8. NEED
#           9. COLD
#           10.MARS
#
# Enter a letter to guess: life
#
# 		Better Luck Next Time..🙂🙂
